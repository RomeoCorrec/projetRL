# %%
# !pip install imageio
from IPython import get_ipython
from IPython.display import display, Video
import imageio
from IPython.display import display, Video
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
from collections import deque
import cv2 # Import cv2
# Out:
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (2.37.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from imageio) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio) (11.1.0)

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
GAMMA = 0.99
BATCH_SIZE = 64
LR = 1e-3
MEMORY_SIZE = 10000
EPSILON_START = 1.0
EPSILON_END = 0.01
NUM_EPISODES = 500
EPSILON_DECAY = NUM_EPISODES
TARGET_UPDATE = 10

# %%
# Environment setup
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# Q-Network class
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Initialize networks
policy_net = DQN(state_size, action_size).to(device)
target_net = DQN(state_size, action_size).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=LR)
memory = deque(maxlen=MEMORY_SIZE)
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
# Epsilon-greedy action selection
def select_action(state, epsilon):
    if random.random() < epsilon:
        return env.action_space.sample()
    with torch.no_grad():
        state = torch.FloatTensor(state).unsqueeze(0).to(device)
        return policy_net(state).argmax(dim=1).item()

# Store transitions in memory
def store_transition(state, action, reward, next_state, done):
    # Ensure state and next_state are in the expected format
    if isinstance(state, np.ndarray) and state.shape != (4,):
      state = np.array(state[:4])
    if isinstance(next_state, np.ndarray) and next_state.shape != (4,):
      next_state = np.array(next_state[:4])
    memory.append((state, action, reward, next_state, done))

# %%
# Training function
def train():
    if len(memory) < BATCH_SIZE:
        return

    batch = random.sample(memory, BATCH_SIZE)
    states, actions, rewards, next_states, dones = zip(*batch)

    # convert states to a compatible format.
    states = np.array(states)
    if len(states.shape) > 2:
      states = np.reshape(states, (BATCH_SIZE, -1))
    states = torch.tensor(states, dtype=torch.float32).to(device)

    # Same for next_states
    next_states = np.array(next_states)
    if len(next_states.shape) > 2:
        next_states = np.reshape(next_states, (BATCH_SIZE, -1))
    next_states = torch.tensor(next_states, dtype=torch.float32).to(device)

    actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(device)
    rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
    dones = torch.tensor(dones, dtype=torch.float32).to(device)

    # Q-values of the current policy
    q_values = policy_net(states).gather(1, actions).squeeze(1)

    # Double DQN: action selection by policy_net, evaluation by target_net
    next_actions = policy_net(next_states).argmax(dim=1, keepdim=True)
    next_q_values = target_net(next_states).gather(1, next_actions).squeeze(1)
    target_q_values = rewards + (GAMMA * next_q_values * (1 - dones))

    # Loss and optimization
    loss = nn.MSELoss()(q_values, target_q_values.detach())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
def generate_video(network, env_name="CartPole-v1", num_episodes=1, max_steps_per_episode=2000, video_filename='cartpole_trained_model.mp4'):
    frames = []
    env = gym.make(env_name, render_mode="rgb_array")

    for episode in range(num_episodes):
        state = env.reset()
        terminal = False
        current_step = 0
        # Removed preprocessing code that was specific to atari games.

        while not terminal and current_step < max_steps_per_episode:
            frame = env.render()

            if isinstance(frame, list):
              frame = np.array(frame)

            # Corriger la forme de l'image si elle contient une dimension superflue
            if frame is not None and len(frame.shape) == 4 and frame.shape[0] == 1:
                frame = np.squeeze(frame, axis=0)  # Supprime la première dimension

            # Vérification de la forme correcte (400, 600, 3)
            if frame is not None and frame.shape == (400, 600, 3):
                frames.append(frame)
            else:
                print(f"Image ignorée à l'étape {current_step} : format inattendu {frame.shape if frame is not None else 'None'}")

            # Prendre une action selon le modèle entraîné
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            action = network(state_tensor).argmax(dim=1).item()

            next_state, reward, terminal, _ = env.step(action)
            # no longer needs to preprocess next_state since it is no longer an atari game.
            state = next_state
            current_step += 1

    env.close()

    # Enregistrer les frames en une vidéo
    if frames:
        imageio.mimsave(video_filename, frames, fps=30)
        display(Video(video_filename, embed=True))
    else:
        print("No frames captured.")

# %%
# Main training loop
epsilon = EPSILON_START
rewards_per_episode_1 = []
for episode in range(NUM_EPISODES):
    state = env.reset() # reset the env to get the observations in the correct format.
    total_reward = 0

    # Ensure state is in the correct format
    if isinstance(state, np.ndarray) and state.shape != (4,):
      state = np.array(state[:4])

    for t in range(1000):
        action = select_action(state, epsilon)
        next_state, reward, done, _ = env.step(action)

        # ensure next_state is in the correct format.
        if isinstance(next_state, np.ndarray) and next_state.shape != (4,):
          next_state = np.array(next_state[:4])

        store_transition(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        train()

        if done:
            break

    # Epsilon decay
    epsilon = max(EPSILON_END, EPSILON_START - episode / EPSILON_DECAY)
    rewards_per_episode_1.append(total_reward)
    # Update target network
    if episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
    if episode % 100 == 0:
      generate_video(policy_net)

    print(f"Episode {episode}, Total Reward: {total_reward}, Epsilon: {epsilon:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 0, Total Reward: 30.0, Epsilon: 1.00
# Episode 1, Total Reward: 13.0, Epsilon: 1.00
# Episode 2, Total Reward: 39.0, Epsilon: 1.00
# Episode 3, Total Reward: 25.0, Epsilon: 0.99
# Episode 4, Total Reward: 22.0, Epsilon: 0.99
# Episode 5, Total Reward: 16.0, Epsilon: 0.99
# Episode 6, Total Reward: 12.0, Epsilon: 0.99
# Episode 7, Total Reward: 28.0, Epsilon: 0.99
# Episode 8, Total Reward: 8.0, Epsilon: 0.98
# Episode 9, Total Reward: 14.0, Epsilon: 0.98
# Episode 10, Total Reward: 22.0, Epsilon: 0.98
# Episode 11, Total Reward: 12.0, Epsilon: 0.98
# Episode 12, Total Reward: 61.0, Epsilon: 0.98
# Episode 13, Total Reward: 17.0, Epsilon: 0.97
# Episode 14, Total Reward: 32.0, Epsilon: 0.97
# Episode 15, Total Reward: 46.0, Epsilon: 0.97
# Episode 16, Total Reward: 15.0, Epsilon: 0.97
# Episode 17, Total Reward: 65.0, Epsilon: 0.97
# Episode 18, Total Reward: 42.0, Epsilon: 0.96
# Episode 19, Total Reward: 12.0, Epsilon: 0.96
# Episode 20, Total Reward: 20.0, Epsilon: 0.96
# Episode 21, Total Reward: 28.0, Epsilon: 0.96
# Episode 22, Total Reward: 21.0, Epsilon: 0.96
# Episode 23, Total Reward: 21.0, Epsilon: 0.95
# Episode 24, Total Reward: 12.0, Epsilon: 0.95
# Episode 25, Total Reward: 13.0, Epsilon: 0.95
# Episode 26, Total Reward: 29.0, Epsilon: 0.95
# Episode 27, Total Reward: 17.0, Epsilon: 0.95
# Episode 28, Total Reward: 9.0, Epsilon: 0.94
# Episode 29, Total Reward: 26.0, Epsilon: 0.94
# Episode 30, Total Reward: 13.0, Epsilon: 0.94
# Episode 31, Total Reward: 16.0, Epsilon: 0.94
# Episode 32, Total Reward: 16.0, Epsilon: 0.94
# Episode 33, Total Reward: 23.0, Epsilon: 0.93
# Episode 34, Total Reward: 15.0, Epsilon: 0.93
# Episode 35, Total Reward: 21.0, Epsilon: 0.93
# Episode 36, Total Reward: 16.0, Epsilon: 0.93
# Episode 37, Total Reward: 12.0, Epsilon: 0.93
# Episode 38, Total Reward: 28.0, Epsilon: 0.92
# Episode 39, Total Reward: 71.0, Epsilon: 0.92
# Episode 40, Total Reward: 18.0, Epsilon: 0.92
# Episode 41, Total Reward: 37.0, Epsilon: 0.92
# Episode 42, Total Reward: 27.0, Epsilon: 0.92
# Episode 43, Total Reward: 14.0, Epsilon: 0.91
# Episode 44, Total Reward: 47.0, Epsilon: 0.91
# Episode 45, Total Reward: 15.0, Epsilon: 0.91
# Episode 46, Total Reward: 14.0, Epsilon: 0.91
# Episode 47, Total Reward: 55.0, Epsilon: 0.91
# Episode 48, Total Reward: 14.0, Epsilon: 0.90
# Episode 49, Total Reward: 22.0, Epsilon: 0.90
# Episode 50, Total Reward: 16.0, Epsilon: 0.90
# Episode 51, Total Reward: 28.0, Epsilon: 0.90
# Episode 52, Total Reward: 30.0, Epsilon: 0.90
# Episode 53, Total Reward: 17.0, Epsilon: 0.89
# Episode 54, Total Reward: 53.0, Epsilon: 0.89
# Episode 55, Total Reward: 37.0, Epsilon: 0.89
# Episode 56, Total Reward: 16.0, Epsilon: 0.89
# Episode 57, Total Reward: 16.0, Epsilon: 0.89
# Episode 58, Total Reward: 16.0, Epsilon: 0.88
# Episode 59, Total Reward: 24.0, Epsilon: 0.88
# Episode 60, Total Reward: 20.0, Epsilon: 0.88
# Episode 61, Total Reward: 27.0, Epsilon: 0.88
# Episode 62, Total Reward: 29.0, Epsilon: 0.88
# Episode 63, Total Reward: 18.0, Epsilon: 0.87
# Episode 64, Total Reward: 38.0, Epsilon: 0.87
# Episode 65, Total Reward: 28.0, Epsilon: 0.87
# Episode 66, Total Reward: 18.0, Epsilon: 0.87
# Episode 67, Total Reward: 17.0, Epsilon: 0.87
# Episode 68, Total Reward: 63.0, Epsilon: 0.86
# Episode 69, Total Reward: 10.0, Epsilon: 0.86
# Episode 70, Total Reward: 12.0, Epsilon: 0.86
# Episode 71, Total Reward: 16.0, Epsilon: 0.86
# Episode 72, Total Reward: 28.0, Epsilon: 0.86
# Episode 73, Total Reward: 15.0, Epsilon: 0.85
# Episode 74, Total Reward: 30.0, Epsilon: 0.85
# Episode 75, Total Reward: 18.0, Epsilon: 0.85
# Episode 76, Total Reward: 24.0, Epsilon: 0.85
# Episode 77, Total Reward: 38.0, Epsilon: 0.85
# Episode 78, Total Reward: 39.0, Epsilon: 0.84
# Episode 79, Total Reward: 51.0, Epsilon: 0.84
# Episode 80, Total Reward: 28.0, Epsilon: 0.84
# Episode 81, Total Reward: 28.0, Epsilon: 0.84
# Episode 82, Total Reward: 24.0, Epsilon: 0.84
# Episode 83, Total Reward: 13.0, Epsilon: 0.83
# Episode 84, Total Reward: 11.0, Epsilon: 0.83
# Episode 85, Total Reward: 24.0, Epsilon: 0.83
# Episode 86, Total Reward: 21.0, Epsilon: 0.83
# Episode 87, Total Reward: 44.0, Epsilon: 0.83
# Episode 88, Total Reward: 48.0, Epsilon: 0.82
# Episode 89, Total Reward: 23.0, Epsilon: 0.82
# Episode 90, Total Reward: 42.0, Epsilon: 0.82
# Episode 91, Total Reward: 14.0, Epsilon: 0.82
# Episode 92, Total Reward: 33.0, Epsilon: 0.82
# Episode 93, Total Reward: 16.0, Epsilon: 0.81
# Episode 94, Total Reward: 23.0, Epsilon: 0.81
# Episode 95, Total Reward: 14.0, Epsilon: 0.81
# Episode 96, Total Reward: 12.0, Epsilon: 0.81
# Episode 97, Total Reward: 41.0, Epsilon: 0.81
# Episode 98, Total Reward: 23.0, Epsilon: 0.80
# Episode 99, Total Reward: 81.0, Epsilon: 0.80
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 100, Total Reward: 15.0, Epsilon: 0.80
# Episode 101, Total Reward: 38.0, Epsilon: 0.80
# Episode 102, Total Reward: 10.0, Epsilon: 0.80
# Episode 103, Total Reward: 14.0, Epsilon: 0.79
# Episode 104, Total Reward: 53.0, Epsilon: 0.79
# Episode 105, Total Reward: 22.0, Epsilon: 0.79
# Episode 106, Total Reward: 36.0, Epsilon: 0.79
# Episode 107, Total Reward: 28.0, Epsilon: 0.79
# Episode 108, Total Reward: 31.0, Epsilon: 0.78
# Episode 109, Total Reward: 85.0, Epsilon: 0.78
# Episode 110, Total Reward: 25.0, Epsilon: 0.78
# Episode 111, Total Reward: 11.0, Epsilon: 0.78
# Episode 112, Total Reward: 36.0, Epsilon: 0.78
# Episode 113, Total Reward: 137.0, Epsilon: 0.77
# Episode 114, Total Reward: 62.0, Epsilon: 0.77
# Episode 115, Total Reward: 22.0, Epsilon: 0.77
# Episode 116, Total Reward: 26.0, Epsilon: 0.77
# Episode 117, Total Reward: 22.0, Epsilon: 0.77
# Episode 118, Total Reward: 17.0, Epsilon: 0.76
# Episode 119, Total Reward: 98.0, Epsilon: 0.76
# Episode 120, Total Reward: 25.0, Epsilon: 0.76
# Episode 121, Total Reward: 21.0, Epsilon: 0.76
# Episode 122, Total Reward: 24.0, Epsilon: 0.76
# Episode 123, Total Reward: 27.0, Epsilon: 0.75
# Episode 124, Total Reward: 98.0, Epsilon: 0.75
# Episode 125, Total Reward: 12.0, Epsilon: 0.75
# Episode 126, Total Reward: 25.0, Epsilon: 0.75
# Episode 127, Total Reward: 26.0, Epsilon: 0.75
# Episode 128, Total Reward: 18.0, Epsilon: 0.74
# Episode 129, Total Reward: 37.0, Epsilon: 0.74
# Episode 130, Total Reward: 42.0, Epsilon: 0.74
# Episode 131, Total Reward: 23.0, Epsilon: 0.74
# Episode 132, Total Reward: 21.0, Epsilon: 0.74
# Episode 133, Total Reward: 19.0, Epsilon: 0.73
# Episode 134, Total Reward: 61.0, Epsilon: 0.73
# Episode 135, Total Reward: 61.0, Epsilon: 0.73
# Episode 136, Total Reward: 27.0, Epsilon: 0.73
# Episode 137, Total Reward: 37.0, Epsilon: 0.73
# Episode 138, Total Reward: 40.0, Epsilon: 0.72
# Episode 139, Total Reward: 25.0, Epsilon: 0.72
# Episode 140, Total Reward: 44.0, Epsilon: 0.72
# Episode 141, Total Reward: 26.0, Epsilon: 0.72
# Episode 142, Total Reward: 20.0, Epsilon: 0.72
# Episode 143, Total Reward: 65.0, Epsilon: 0.71
# Episode 144, Total Reward: 74.0, Epsilon: 0.71
# Episode 145, Total Reward: 58.0, Epsilon: 0.71
# Episode 146, Total Reward: 24.0, Epsilon: 0.71
# Episode 147, Total Reward: 13.0, Epsilon: 0.71
# Episode 148, Total Reward: 21.0, Epsilon: 0.70
# Episode 149, Total Reward: 155.0, Epsilon: 0.70
# Episode 150, Total Reward: 63.0, Epsilon: 0.70
# Episode 151, Total Reward: 75.0, Epsilon: 0.70
# Episode 152, Total Reward: 104.0, Epsilon: 0.70
# Episode 153, Total Reward: 29.0, Epsilon: 0.69
# Episode 154, Total Reward: 104.0, Epsilon: 0.69
# Episode 155, Total Reward: 23.0, Epsilon: 0.69
# Episode 156, Total Reward: 21.0, Epsilon: 0.69
# Episode 157, Total Reward: 95.0, Epsilon: 0.69
# Episode 158, Total Reward: 28.0, Epsilon: 0.68
# Episode 159, Total Reward: 69.0, Epsilon: 0.68
# Episode 160, Total Reward: 35.0, Epsilon: 0.68
# Episode 161, Total Reward: 40.0, Epsilon: 0.68
# Episode 162, Total Reward: 55.0, Epsilon: 0.68
# Episode 163, Total Reward: 18.0, Epsilon: 0.67
# Episode 164, Total Reward: 19.0, Epsilon: 0.67
# Episode 165, Total Reward: 18.0, Epsilon: 0.67
# Episode 166, Total Reward: 83.0, Epsilon: 0.67
# Episode 167, Total Reward: 32.0, Epsilon: 0.67
# Episode 168, Total Reward: 14.0, Epsilon: 0.66
# Episode 169, Total Reward: 92.0, Epsilon: 0.66
# Episode 170, Total Reward: 51.0, Epsilon: 0.66
# Episode 171, Total Reward: 25.0, Epsilon: 0.66
# Episode 172, Total Reward: 19.0, Epsilon: 0.66
# Episode 173, Total Reward: 23.0, Epsilon: 0.65
# Episode 174, Total Reward: 89.0, Epsilon: 0.65
# Episode 175, Total Reward: 23.0, Epsilon: 0.65
# Episode 176, Total Reward: 42.0, Epsilon: 0.65
# Episode 177, Total Reward: 29.0, Epsilon: 0.65
# Episode 178, Total Reward: 9.0, Epsilon: 0.64
# Episode 179, Total Reward: 47.0, Epsilon: 0.64
# Episode 180, Total Reward: 116.0, Epsilon: 0.64
# Episode 181, Total Reward: 27.0, Epsilon: 0.64
# Episode 182, Total Reward: 55.0, Epsilon: 0.64
# Episode 183, Total Reward: 76.0, Epsilon: 0.63
# Episode 184, Total Reward: 35.0, Epsilon: 0.63
# Episode 185, Total Reward: 28.0, Epsilon: 0.63
# Episode 186, Total Reward: 12.0, Epsilon: 0.63
# Episode 187, Total Reward: 132.0, Epsilon: 0.63
# Episode 188, Total Reward: 49.0, Epsilon: 0.62
# Episode 189, Total Reward: 66.0, Epsilon: 0.62
# Episode 190, Total Reward: 152.0, Epsilon: 0.62
# Episode 191, Total Reward: 81.0, Epsilon: 0.62
# Episode 192, Total Reward: 52.0, Epsilon: 0.62
# Episode 193, Total Reward: 54.0, Epsilon: 0.61
# Episode 194, Total Reward: 93.0, Epsilon: 0.61
# Episode 195, Total Reward: 18.0, Epsilon: 0.61
# Episode 196, Total Reward: 158.0, Epsilon: 0.61
# Episode 197, Total Reward: 42.0, Epsilon: 0.61
# Episode 198, Total Reward: 10.0, Epsilon: 0.60
# Episode 199, Total Reward: 19.0, Epsilon: 0.60
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 200, Total Reward: 83.0, Epsilon: 0.60
# Episode 201, Total Reward: 50.0, Epsilon: 0.60
# Episode 202, Total Reward: 31.0, Epsilon: 0.60
# Episode 203, Total Reward: 12.0, Epsilon: 0.59
# Episode 204, Total Reward: 46.0, Epsilon: 0.59
# Episode 205, Total Reward: 35.0, Epsilon: 0.59
# Episode 206, Total Reward: 26.0, Epsilon: 0.59
# Episode 207, Total Reward: 87.0, Epsilon: 0.59
# Episode 208, Total Reward: 53.0, Epsilon: 0.58
# Episode 209, Total Reward: 143.0, Epsilon: 0.58
# Episode 210, Total Reward: 65.0, Epsilon: 0.58
# Episode 211, Total Reward: 21.0, Epsilon: 0.58
# Episode 212, Total Reward: 24.0, Epsilon: 0.58
# Episode 213, Total Reward: 21.0, Epsilon: 0.57
# Episode 214, Total Reward: 16.0, Epsilon: 0.57
# Episode 215, Total Reward: 125.0, Epsilon: 0.57
# Episode 216, Total Reward: 60.0, Epsilon: 0.57
# Episode 217, Total Reward: 40.0, Epsilon: 0.57
# Episode 218, Total Reward: 12.0, Epsilon: 0.56
# Episode 219, Total Reward: 23.0, Epsilon: 0.56
# Episode 220, Total Reward: 28.0, Epsilon: 0.56
# Episode 221, Total Reward: 32.0, Epsilon: 0.56
# Episode 222, Total Reward: 35.0, Epsilon: 0.56
# Episode 223, Total Reward: 36.0, Epsilon: 0.55
# Episode 224, Total Reward: 27.0, Epsilon: 0.55
# Episode 225, Total Reward: 87.0, Epsilon: 0.55
# Episode 226, Total Reward: 63.0, Epsilon: 0.55
# Episode 227, Total Reward: 65.0, Epsilon: 0.55
# Episode 228, Total Reward: 111.0, Epsilon: 0.54
# Episode 229, Total Reward: 22.0, Epsilon: 0.54
# Episode 230, Total Reward: 61.0, Epsilon: 0.54
# Episode 231, Total Reward: 15.0, Epsilon: 0.54
# Episode 232, Total Reward: 21.0, Epsilon: 0.54
# Episode 233, Total Reward: 46.0, Epsilon: 0.53
# Episode 234, Total Reward: 38.0, Epsilon: 0.53
# Episode 235, Total Reward: 22.0, Epsilon: 0.53
# Episode 236, Total Reward: 88.0, Epsilon: 0.53
# Episode 237, Total Reward: 17.0, Epsilon: 0.53
# Episode 238, Total Reward: 99.0, Epsilon: 0.52
# Episode 239, Total Reward: 38.0, Epsilon: 0.52
# Episode 240, Total Reward: 47.0, Epsilon: 0.52
# Episode 241, Total Reward: 20.0, Epsilon: 0.52
# Episode 242, Total Reward: 47.0, Epsilon: 0.52
# Episode 243, Total Reward: 65.0, Epsilon: 0.51
# Episode 244, Total Reward: 22.0, Epsilon: 0.51
# Episode 245, Total Reward: 72.0, Epsilon: 0.51
# Episode 246, Total Reward: 31.0, Epsilon: 0.51
# Episode 247, Total Reward: 63.0, Epsilon: 0.51
# Episode 248, Total Reward: 23.0, Epsilon: 0.50
# Episode 249, Total Reward: 26.0, Epsilon: 0.50
# Episode 250, Total Reward: 98.0, Epsilon: 0.50
# Episode 251, Total Reward: 12.0, Epsilon: 0.50
# Episode 252, Total Reward: 60.0, Epsilon: 0.50
# Episode 253, Total Reward: 40.0, Epsilon: 0.49
# Episode 254, Total Reward: 165.0, Epsilon: 0.49
# Episode 255, Total Reward: 40.0, Epsilon: 0.49
# Episode 256, Total Reward: 123.0, Epsilon: 0.49
# Episode 257, Total Reward: 25.0, Epsilon: 0.49
# Episode 258, Total Reward: 32.0, Epsilon: 0.48
# Episode 259, Total Reward: 100.0, Epsilon: 0.48
# Episode 260, Total Reward: 50.0, Epsilon: 0.48
# Episode 261, Total Reward: 91.0, Epsilon: 0.48
# Episode 262, Total Reward: 21.0, Epsilon: 0.48
# Episode 263, Total Reward: 61.0, Epsilon: 0.47
# Episode 264, Total Reward: 61.0, Epsilon: 0.47
# Episode 265, Total Reward: 43.0, Epsilon: 0.47
# Episode 266, Total Reward: 22.0, Epsilon: 0.47
# Episode 267, Total Reward: 18.0, Epsilon: 0.47
# Episode 268, Total Reward: 40.0, Epsilon: 0.46
# Episode 269, Total Reward: 27.0, Epsilon: 0.46
# Episode 270, Total Reward: 24.0, Epsilon: 0.46
# Episode 271, Total Reward: 16.0, Epsilon: 0.46
# Episode 272, Total Reward: 22.0, Epsilon: 0.46
# Episode 273, Total Reward: 32.0, Epsilon: 0.45
# Episode 274, Total Reward: 16.0, Epsilon: 0.45
# Episode 275, Total Reward: 92.0, Epsilon: 0.45
# Episode 276, Total Reward: 176.0, Epsilon: 0.45
# Episode 277, Total Reward: 71.0, Epsilon: 0.45
# Episode 278, Total Reward: 52.0, Epsilon: 0.44
# Episode 279, Total Reward: 16.0, Epsilon: 0.44
# Episode 280, Total Reward: 55.0, Epsilon: 0.44
# Episode 281, Total Reward: 40.0, Epsilon: 0.44
# Episode 282, Total Reward: 22.0, Epsilon: 0.44
# Episode 283, Total Reward: 168.0, Epsilon: 0.43
# Episode 284, Total Reward: 123.0, Epsilon: 0.43
# Episode 285, Total Reward: 51.0, Epsilon: 0.43
# Episode 286, Total Reward: 9.0, Epsilon: 0.43
# Episode 287, Total Reward: 13.0, Epsilon: 0.43
# Episode 288, Total Reward: 20.0, Epsilon: 0.42
# Episode 289, Total Reward: 26.0, Epsilon: 0.42
# Episode 290, Total Reward: 90.0, Epsilon: 0.42
# Episode 291, Total Reward: 18.0, Epsilon: 0.42
# Episode 292, Total Reward: 68.0, Epsilon: 0.42
# Episode 293, Total Reward: 37.0, Epsilon: 0.41
# Episode 294, Total Reward: 110.0, Epsilon: 0.41
# Episode 295, Total Reward: 132.0, Epsilon: 0.41
# Episode 296, Total Reward: 123.0, Epsilon: 0.41
# Episode 297, Total Reward: 141.0, Epsilon: 0.41
# Episode 298, Total Reward: 72.0, Epsilon: 0.40
# Episode 299, Total Reward: 64.0, Epsilon: 0.40
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 300, Total Reward: 133.0, Epsilon: 0.40
# Episode 301, Total Reward: 197.0, Epsilon: 0.40
# Episode 302, Total Reward: 114.0, Epsilon: 0.40
# Episode 303, Total Reward: 48.0, Epsilon: 0.39
# Episode 304, Total Reward: 83.0, Epsilon: 0.39
# Episode 305, Total Reward: 40.0, Epsilon: 0.39
# Episode 306, Total Reward: 97.0, Epsilon: 0.39
# Episode 307, Total Reward: 14.0, Epsilon: 0.39
# Episode 308, Total Reward: 47.0, Epsilon: 0.38
# Episode 309, Total Reward: 75.0, Epsilon: 0.38
# Episode 310, Total Reward: 91.0, Epsilon: 0.38
# Episode 311, Total Reward: 136.0, Epsilon: 0.38
# Episode 312, Total Reward: 17.0, Epsilon: 0.38
# Episode 313, Total Reward: 75.0, Epsilon: 0.37
# Episode 314, Total Reward: 39.0, Epsilon: 0.37
# Episode 315, Total Reward: 94.0, Epsilon: 0.37
# Episode 316, Total Reward: 25.0, Epsilon: 0.37
# Episode 317, Total Reward: 138.0, Epsilon: 0.37
# Episode 318, Total Reward: 108.0, Epsilon: 0.36
# Episode 319, Total Reward: 11.0, Epsilon: 0.36
# Episode 320, Total Reward: 122.0, Epsilon: 0.36
# Episode 321, Total Reward: 19.0, Epsilon: 0.36
# Episode 322, Total Reward: 143.0, Epsilon: 0.36
# Episode 323, Total Reward: 33.0, Epsilon: 0.35
# Episode 324, Total Reward: 125.0, Epsilon: 0.35
# Episode 325, Total Reward: 13.0, Epsilon: 0.35
# Episode 326, Total Reward: 22.0, Epsilon: 0.35
# Episode 327, Total Reward: 126.0, Epsilon: 0.35
# Episode 328, Total Reward: 122.0, Epsilon: 0.34
# Episode 329, Total Reward: 126.0, Epsilon: 0.34
# Episode 330, Total Reward: 44.0, Epsilon: 0.34
# Episode 331, Total Reward: 63.0, Epsilon: 0.34
# Episode 332, Total Reward: 10.0, Epsilon: 0.34
# Episode 333, Total Reward: 34.0, Epsilon: 0.33
# Episode 334, Total Reward: 109.0, Epsilon: 0.33
# Episode 335, Total Reward: 106.0, Epsilon: 0.33
# Episode 336, Total Reward: 27.0, Epsilon: 0.33
# Episode 337, Total Reward: 119.0, Epsilon: 0.33
# Episode 338, Total Reward: 117.0, Epsilon: 0.32
# Episode 339, Total Reward: 33.0, Epsilon: 0.32
# Episode 340, Total Reward: 113.0, Epsilon: 0.32
# Episode 341, Total Reward: 111.0, Epsilon: 0.32
# Episode 342, Total Reward: 138.0, Epsilon: 0.32
# Episode 343, Total Reward: 20.0, Epsilon: 0.31
# Episode 344, Total Reward: 36.0, Epsilon: 0.31
# Episode 345, Total Reward: 34.0, Epsilon: 0.31
# Episode 346, Total Reward: 111.0, Epsilon: 0.31
# Episode 347, Total Reward: 18.0, Epsilon: 0.31
# Episode 348, Total Reward: 113.0, Epsilon: 0.30
# Episode 349, Total Reward: 110.0, Epsilon: 0.30
# Episode 350, Total Reward: 114.0, Epsilon: 0.30
# Episode 351, Total Reward: 118.0, Epsilon: 0.30
# Episode 352, Total Reward: 144.0, Epsilon: 0.30
# Episode 353, Total Reward: 45.0, Epsilon: 0.29
# Episode 354, Total Reward: 10.0, Epsilon: 0.29
# Episode 355, Total Reward: 69.0, Epsilon: 0.29
# Episode 356, Total Reward: 55.0, Epsilon: 0.29
# Episode 357, Total Reward: 120.0, Epsilon: 0.29
# Episode 358, Total Reward: 38.0, Epsilon: 0.28
# Episode 359, Total Reward: 86.0, Epsilon: 0.28
# Episode 360, Total Reward: 99.0, Epsilon: 0.28
# Episode 361, Total Reward: 14.0, Epsilon: 0.28
# Episode 362, Total Reward: 116.0, Epsilon: 0.28
# Episode 363, Total Reward: 16.0, Epsilon: 0.27
# Episode 364, Total Reward: 26.0, Epsilon: 0.27
# Episode 365, Total Reward: 103.0, Epsilon: 0.27
# Episode 366, Total Reward: 14.0, Epsilon: 0.27
# Episode 367, Total Reward: 114.0, Epsilon: 0.27
# Episode 368, Total Reward: 127.0, Epsilon: 0.26
# Episode 369, Total Reward: 68.0, Epsilon: 0.26
# Episode 370, Total Reward: 154.0, Epsilon: 0.26
# Episode 371, Total Reward: 39.0, Epsilon: 0.26
# Episode 372, Total Reward: 26.0, Epsilon: 0.26
# Episode 373, Total Reward: 104.0, Epsilon: 0.25
# Episode 374, Total Reward: 257.0, Epsilon: 0.25
# Episode 375, Total Reward: 108.0, Epsilon: 0.25
# Episode 376, Total Reward: 99.0, Epsilon: 0.25
# Episode 377, Total Reward: 24.0, Epsilon: 0.25
# Episode 378, Total Reward: 50.0, Epsilon: 0.24
# Episode 379, Total Reward: 116.0, Epsilon: 0.24
# Episode 380, Total Reward: 111.0, Epsilon: 0.24
# Episode 381, Total Reward: 11.0, Epsilon: 0.24
# Episode 382, Total Reward: 101.0, Epsilon: 0.24
# Episode 383, Total Reward: 109.0, Epsilon: 0.23
# Episode 384, Total Reward: 68.0, Epsilon: 0.23
# Episode 385, Total Reward: 118.0, Epsilon: 0.23
# Episode 386, Total Reward: 109.0, Epsilon: 0.23
# Episode 387, Total Reward: 125.0, Epsilon: 0.23
# Episode 388, Total Reward: 121.0, Epsilon: 0.22
# Episode 389, Total Reward: 118.0, Epsilon: 0.22
# Episode 390, Total Reward: 18.0, Epsilon: 0.22
# Episode 391, Total Reward: 89.0, Epsilon: 0.22
# Episode 392, Total Reward: 225.0, Epsilon: 0.22
# Episode 393, Total Reward: 110.0, Epsilon: 0.21
# Episode 394, Total Reward: 111.0, Epsilon: 0.21
# Episode 395, Total Reward: 124.0, Epsilon: 0.21
# Episode 396, Total Reward: 138.0, Epsilon: 0.21
# Episode 397, Total Reward: 111.0, Epsilon: 0.21
# Episode 398, Total Reward: 215.0, Epsilon: 0.20
# Episode 399, Total Reward: 117.0, Epsilon: 0.20
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 400, Total Reward: 18.0, Epsilon: 0.20
# Episode 401, Total Reward: 121.0, Epsilon: 0.20
# Episode 402, Total Reward: 118.0, Epsilon: 0.20
# Episode 403, Total Reward: 118.0, Epsilon: 0.19
# Episode 404, Total Reward: 106.0, Epsilon: 0.19
# Episode 405, Total Reward: 123.0, Epsilon: 0.19
# Episode 406, Total Reward: 138.0, Epsilon: 0.19
# Episode 407, Total Reward: 116.0, Epsilon: 0.19
# Episode 408, Total Reward: 112.0, Epsilon: 0.18
# Episode 409, Total Reward: 128.0, Epsilon: 0.18
# Episode 410, Total Reward: 129.0, Epsilon: 0.18
# Episode 411, Total Reward: 98.0, Epsilon: 0.18
# Episode 412, Total Reward: 114.0, Epsilon: 0.18
# Episode 413, Total Reward: 111.0, Epsilon: 0.17
# Episode 414, Total Reward: 66.0, Epsilon: 0.17
# Episode 415, Total Reward: 114.0, Epsilon: 0.17
# Episode 416, Total Reward: 115.0, Epsilon: 0.17
# Episode 417, Total Reward: 119.0, Epsilon: 0.17
# Episode 418, Total Reward: 117.0, Epsilon: 0.16
# Episode 419, Total Reward: 127.0, Epsilon: 0.16
# Episode 420, Total Reward: 128.0, Epsilon: 0.16
# Episode 421, Total Reward: 58.0, Epsilon: 0.16
# Episode 422, Total Reward: 89.0, Epsilon: 0.16
# Episode 423, Total Reward: 111.0, Epsilon: 0.15
# Episode 424, Total Reward: 125.0, Epsilon: 0.15
# Episode 425, Total Reward: 186.0, Epsilon: 0.15
# Episode 426, Total Reward: 127.0, Epsilon: 0.15
# Episode 427, Total Reward: 136.0, Epsilon: 0.15
# Episode 428, Total Reward: 124.0, Epsilon: 0.14
# Episode 429, Total Reward: 128.0, Epsilon: 0.14
# Episode 430, Total Reward: 122.0, Epsilon: 0.14
# Episode 431, Total Reward: 47.0, Epsilon: 0.14
# Episode 432, Total Reward: 123.0, Epsilon: 0.14
# Episode 433, Total Reward: 130.0, Epsilon: 0.13
# Episode 434, Total Reward: 132.0, Epsilon: 0.13
# Episode 435, Total Reward: 128.0, Epsilon: 0.13
# Episode 436, Total Reward: 122.0, Epsilon: 0.13
# Episode 437, Total Reward: 130.0, Epsilon: 0.13
# Episode 438, Total Reward: 125.0, Epsilon: 0.12
# Episode 439, Total Reward: 132.0, Epsilon: 0.12
# Episode 440, Total Reward: 119.0, Epsilon: 0.12
# Episode 441, Total Reward: 236.0, Epsilon: 0.12
# Episode 442, Total Reward: 221.0, Epsilon: 0.12
# Episode 443, Total Reward: 187.0, Epsilon: 0.11
# Episode 444, Total Reward: 220.0, Epsilon: 0.11
# Episode 445, Total Reward: 179.0, Epsilon: 0.11
# Episode 446, Total Reward: 218.0, Epsilon: 0.11
# Episode 447, Total Reward: 194.0, Epsilon: 0.11
# Episode 448, Total Reward: 227.0, Epsilon: 0.10
# Episode 449, Total Reward: 197.0, Epsilon: 0.10
# Episode 450, Total Reward: 186.0, Epsilon: 0.10
# Episode 451, Total Reward: 174.0, Epsilon: 0.10
# Episode 452, Total Reward: 209.0, Epsilon: 0.10
# Episode 453, Total Reward: 216.0, Epsilon: 0.09
# Episode 454, Total Reward: 138.0, Epsilon: 0.09
# Episode 455, Total Reward: 270.0, Epsilon: 0.09
# Episode 456, Total Reward: 189.0, Epsilon: 0.09
# Episode 457, Total Reward: 201.0, Epsilon: 0.09
# Episode 458, Total Reward: 349.0, Epsilon: 0.08
# Episode 459, Total Reward: 270.0, Epsilon: 0.08
# Episode 460, Total Reward: 233.0, Epsilon: 0.08
# Episode 461, Total Reward: 500.0, Epsilon: 0.08
# Episode 462, Total Reward: 183.0, Epsilon: 0.08
# Episode 463, Total Reward: 500.0, Epsilon: 0.07
# Episode 464, Total Reward: 394.0, Epsilon: 0.07
# Episode 465, Total Reward: 237.0, Epsilon: 0.07
# Episode 466, Total Reward: 84.0, Epsilon: 0.07
# Episode 467, Total Reward: 476.0, Epsilon: 0.07
# Episode 468, Total Reward: 202.0, Epsilon: 0.06
# Episode 469, Total Reward: 299.0, Epsilon: 0.06
# Episode 470, Total Reward: 209.0, Epsilon: 0.06
# Episode 471, Total Reward: 286.0, Epsilon: 0.06
# Episode 472, Total Reward: 500.0, Epsilon: 0.06
# Episode 473, Total Reward: 309.0, Epsilon: 0.05
# Episode 474, Total Reward: 294.0, Epsilon: 0.05
# Episode 475, Total Reward: 500.0, Epsilon: 0.05
# Episode 476, Total Reward: 500.0, Epsilon: 0.05
# Episode 477, Total Reward: 500.0, Epsilon: 0.05
# Episode 478, Total Reward: 423.0, Epsilon: 0.04
# Episode 479, Total Reward: 500.0, Epsilon: 0.04
# Episode 480, Total Reward: 500.0, Epsilon: 0.04
# Episode 481, Total Reward: 428.0, Epsilon: 0.04
# Episode 482, Total Reward: 313.0, Epsilon: 0.04
# Episode 483, Total Reward: 500.0, Epsilon: 0.03
# Episode 484, Total Reward: 500.0, Epsilon: 0.03
# Episode 485, Total Reward: 285.0, Epsilon: 0.03
# Episode 486, Total Reward: 500.0, Epsilon: 0.03
# Episode 487, Total Reward: 500.0, Epsilon: 0.03
# Episode 488, Total Reward: 295.0, Epsilon: 0.02
# Episode 489, Total Reward: 338.0, Epsilon: 0.02
# Episode 490, Total Reward: 362.0, Epsilon: 0.02
# Episode 491, Total Reward: 446.0, Epsilon: 0.02
# Episode 492, Total Reward: 391.0, Epsilon: 0.02
# Episode 493, Total Reward: 95.0, Epsilon: 0.01
# Episode 494, Total Reward: 500.0, Epsilon: 0.01
# Episode 495, Total Reward: 471.0, Epsilon: 0.01
# Episode 496, Total Reward: 375.0, Epsilon: 0.01
# Episode 497, Total Reward: 500.0, Epsilon: 0.01
# Episode 498, Total Reward: 387.0, Epsilon: 0.01
# Episode 499, Total Reward: 356.0, Epsilon: 0.01

# %%
generate_video(policy_net)
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
from collections import deque
import imageio
from IPython.display import Video, display

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
GAMMA = 0.99
BATCH_SIZE = 64
LR = 1e-3
MEMORY_SIZE = 10000
EPSILON_START = 1.0
EPSILON_END = 0.01
NUM_EPISODES = 500
EPSILON_DECAY = NUM_EPISODES
TARGET_UPDATE = 10
ALPHA = 0.6
BETA_START = 0.4
BETA_INCREMENT = 0.001

# %%
# Environment setup
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %%
# Prioritized Experience Replay class
class PrioritizedReplayBuffer:
    def __init__(self, capacity, alpha):
        self.capacity = capacity
        self.alpha = alpha
        self.buffer = []
        self.priorities = np.zeros((capacity,), dtype=np.float32)
        self.position = 0

    def add(self, state, action, reward, next_state, done, error):
        max_priority = self.priorities.max() if self.buffer else 1.0
        if len(self.buffer) < self.capacity:
            self.buffer.append((state, action, reward, next_state, done))
        else:
            self.buffer[self.position] = (state, action, reward, next_state, done)
        self.priorities[self.position] = max_priority
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size, beta):
        if len(self.buffer) == 0:
            return [], [], [], [], [], []

        priorities = self.priorities[: len(self.buffer)]
        probs = priorities ** self.alpha
        probs /= probs.sum()

        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]

        weights = (len(self.buffer) * probs[indices]) ** (-beta)
        weights /= weights.max()
        weights = torch.tensor(weights, dtype=torch.float32, device=device)

        states, actions, rewards, next_states, dones = zip(*samples)
        return (indices, torch.tensor(np.array(states), dtype=torch.float32).to(device),
                torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(device),
                torch.tensor(rewards, dtype=torch.float32).to(device),
                torch.tensor(np.array(next_states), dtype=torch.float32).to(device),
                torch.tensor(dones, dtype=torch.float32).to(device), weights)

    def update_priorities(self, indices, errors):
        for idx, error in zip(indices, errors.detach().cpu().numpy()):
            self.priorities[idx] = error + 1e-5

# %%
# Q-Network class
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Initialize networks
policy_net = DQN(state_size, action_size).to(device)
target_net = DQN(state_size, action_size).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=LR)
memory = PrioritizedReplayBuffer(MEMORY_SIZE, ALPHA)

# %%
# Epsilon-greedy action selection
def select_action(state, epsilon):
    if random.random() < epsilon:
        return env.action_space.sample()
    with torch.no_grad():
        state = torch.FloatTensor(state).unsqueeze(0).to(device)
        return policy_net(state).argmax(dim=1).item()

# Store transitions in memory
def store_transition(state, action, reward, next_state, done):
    state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
    next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0).to(device)
    with torch.no_grad():
        q_val = policy_net(state_tensor)[0, action].item()
        next_q_val = target_net(next_state_tensor).max(1)[0].item()
        target = reward + (GAMMA * next_q_val * (1 - done))
        error = abs(q_val - target)
    memory.add(state, action, reward, next_state, done, error)

# %%
# Training function
def train(beta):
    if len(memory.buffer) < BATCH_SIZE:
        return

    indices, states, actions, rewards, next_states, dones, weights = memory.sample(BATCH_SIZE, beta)

    # Q-values of the current policy
    q_values = policy_net(states).gather(1, actions).squeeze(1)

    # Double DQN: action selection by policy_net, evaluation by target_net
    next_actions = policy_net(next_states).argmax(dim=1, keepdim=True)
    next_q_values = target_net(next_states).gather(1, next_actions).squeeze(1)
    target_q_values = rewards + (GAMMA * next_q_values * (1 - dones))

    # Loss and optimization
    errors = torch.abs(q_values - target_q_values).detach()
    memory.update_priorities(indices, errors)

    loss = (weights * (q_values - target_q_values.detach()).pow(2)).mean()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
# Main training loop
epsilon = EPSILON_START
beta = BETA_START
rewards_per_episode_2 = []
for episode in range(NUM_EPISODES):
    state = env.reset()
    total_reward = 0

    for t in range(1000):
        action = select_action(state, epsilon)
        next_state, reward, done, _ = env.step(action)
        store_transition(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        train(beta)

        if done:
            break

    # Epsilon and beta decay
    epsilon = max(EPSILON_END, EPSILON_START - episode / EPSILON_DECAY)
    beta = min(1.0, beta + BETA_INCREMENT)
    rewards_per_episode_2.append(total_reward)
    # Update target network
    if episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
    if episode % 100 == 0:
        generate_video(policy_net)

    print(f"Episode {episode}, Total Reward: {total_reward}, Epsilon: {epsilon:.2f}, Beta: {beta:.2f}")
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 0, Total Reward: 41.0, Epsilon: 1.00, Beta: 0.40
# Episode 1, Total Reward: 12.0, Epsilon: 1.00, Beta: 0.40
# Episode 2, Total Reward: 13.0, Epsilon: 1.00, Beta: 0.40
# Episode 3, Total Reward: 19.0, Epsilon: 0.99, Beta: 0.40
# Episode 4, Total Reward: 29.0, Epsilon: 0.99, Beta: 0.41
# Episode 5, Total Reward: 19.0, Epsilon: 0.99, Beta: 0.41
# Episode 6, Total Reward: 10.0, Epsilon: 0.99, Beta: 0.41
# Episode 7, Total Reward: 22.0, Epsilon: 0.99, Beta: 0.41
# Episode 8, Total Reward: 21.0, Epsilon: 0.98, Beta: 0.41
# Episode 9, Total Reward: 20.0, Epsilon: 0.98, Beta: 0.41
# Episode 10, Total Reward: 18.0, Epsilon: 0.98, Beta: 0.41
# Episode 11, Total Reward: 33.0, Epsilon: 0.98, Beta: 0.41
# Episode 12, Total Reward: 15.0, Epsilon: 0.98, Beta: 0.41
# Episode 13, Total Reward: 39.0, Epsilon: 0.97, Beta: 0.41
# Episode 14, Total Reward: 16.0, Epsilon: 0.97, Beta: 0.42
# Episode 15, Total Reward: 12.0, Epsilon: 0.97, Beta: 0.42
# Episode 16, Total Reward: 26.0, Epsilon: 0.97, Beta: 0.42
# Episode 17, Total Reward: 17.0, Epsilon: 0.97, Beta: 0.42
# Episode 18, Total Reward: 15.0, Epsilon: 0.96, Beta: 0.42
# Episode 19, Total Reward: 12.0, Epsilon: 0.96, Beta: 0.42
# Episode 20, Total Reward: 27.0, Epsilon: 0.96, Beta: 0.42
# Episode 21, Total Reward: 26.0, Epsilon: 0.96, Beta: 0.42
# Episode 22, Total Reward: 15.0, Epsilon: 0.96, Beta: 0.42
# Episode 23, Total Reward: 15.0, Epsilon: 0.95, Beta: 0.42
# Episode 24, Total Reward: 15.0, Epsilon: 0.95, Beta: 0.43
# Episode 25, Total Reward: 15.0, Epsilon: 0.95, Beta: 0.43
# Episode 26, Total Reward: 10.0, Epsilon: 0.95, Beta: 0.43
# Episode 27, Total Reward: 13.0, Epsilon: 0.95, Beta: 0.43
# Episode 28, Total Reward: 22.0, Epsilon: 0.94, Beta: 0.43
# Episode 29, Total Reward: 21.0, Epsilon: 0.94, Beta: 0.43
# Episode 30, Total Reward: 16.0, Epsilon: 0.94, Beta: 0.43
# Episode 31, Total Reward: 15.0, Epsilon: 0.94, Beta: 0.43
# Episode 32, Total Reward: 25.0, Epsilon: 0.94, Beta: 0.43
# Episode 33, Total Reward: 49.0, Epsilon: 0.93, Beta: 0.43
# Episode 34, Total Reward: 23.0, Epsilon: 0.93, Beta: 0.44
# Episode 35, Total Reward: 22.0, Epsilon: 0.93, Beta: 0.44
# Episode 36, Total Reward: 21.0, Epsilon: 0.93, Beta: 0.44
# Episode 37, Total Reward: 19.0, Epsilon: 0.93, Beta: 0.44
# Episode 38, Total Reward: 9.0, Epsilon: 0.92, Beta: 0.44
# Episode 39, Total Reward: 15.0, Epsilon: 0.92, Beta: 0.44
# Episode 40, Total Reward: 57.0, Epsilon: 0.92, Beta: 0.44
# Episode 41, Total Reward: 16.0, Epsilon: 0.92, Beta: 0.44
# Episode 42, Total Reward: 10.0, Epsilon: 0.92, Beta: 0.44
# Episode 43, Total Reward: 27.0, Epsilon: 0.91, Beta: 0.44
# Episode 44, Total Reward: 35.0, Epsilon: 0.91, Beta: 0.45
# Episode 45, Total Reward: 13.0, Epsilon: 0.91, Beta: 0.45
# Episode 46, Total Reward: 23.0, Epsilon: 0.91, Beta: 0.45
# Episode 47, Total Reward: 13.0, Epsilon: 0.91, Beta: 0.45
# Episode 48, Total Reward: 32.0, Epsilon: 0.90, Beta: 0.45
# Episode 49, Total Reward: 37.0, Epsilon: 0.90, Beta: 0.45
# Episode 50, Total Reward: 12.0, Epsilon: 0.90, Beta: 0.45
# Episode 51, Total Reward: 17.0, Epsilon: 0.90, Beta: 0.45
# Episode 52, Total Reward: 14.0, Epsilon: 0.90, Beta: 0.45
# Episode 53, Total Reward: 26.0, Epsilon: 0.89, Beta: 0.45
# Episode 54, Total Reward: 15.0, Epsilon: 0.89, Beta: 0.46
# Episode 55, Total Reward: 13.0, Epsilon: 0.89, Beta: 0.46
# Episode 56, Total Reward: 17.0, Epsilon: 0.89, Beta: 0.46
# Episode 57, Total Reward: 23.0, Epsilon: 0.89, Beta: 0.46
# Episode 58, Total Reward: 12.0, Epsilon: 0.88, Beta: 0.46
# Episode 59, Total Reward: 18.0, Epsilon: 0.88, Beta: 0.46
# Episode 60, Total Reward: 27.0, Epsilon: 0.88, Beta: 0.46
# Episode 61, Total Reward: 27.0, Epsilon: 0.88, Beta: 0.46
# Episode 62, Total Reward: 26.0, Epsilon: 0.88, Beta: 0.46
# Episode 63, Total Reward: 39.0, Epsilon: 0.87, Beta: 0.46
# Episode 64, Total Reward: 36.0, Epsilon: 0.87, Beta: 0.47
# Episode 65, Total Reward: 13.0, Epsilon: 0.87, Beta: 0.47
# Episode 66, Total Reward: 49.0, Epsilon: 0.87, Beta: 0.47
# Episode 67, Total Reward: 20.0, Epsilon: 0.87, Beta: 0.47
# Episode 68, Total Reward: 58.0, Epsilon: 0.86, Beta: 0.47
# Episode 69, Total Reward: 12.0, Epsilon: 0.86, Beta: 0.47
# Episode 70, Total Reward: 15.0, Epsilon: 0.86, Beta: 0.47
# Episode 71, Total Reward: 62.0, Epsilon: 0.86, Beta: 0.47
# Episode 72, Total Reward: 25.0, Epsilon: 0.86, Beta: 0.47
# Episode 73, Total Reward: 19.0, Epsilon: 0.85, Beta: 0.47
# Episode 74, Total Reward: 16.0, Epsilon: 0.85, Beta: 0.48
# Episode 75, Total Reward: 16.0, Epsilon: 0.85, Beta: 0.48
# Episode 76, Total Reward: 26.0, Epsilon: 0.85, Beta: 0.48
# Episode 77, Total Reward: 22.0, Epsilon: 0.85, Beta: 0.48
# Episode 78, Total Reward: 26.0, Epsilon: 0.84, Beta: 0.48
# Episode 79, Total Reward: 20.0, Epsilon: 0.84, Beta: 0.48
# Episode 80, Total Reward: 20.0, Epsilon: 0.84, Beta: 0.48
# Episode 81, Total Reward: 18.0, Epsilon: 0.84, Beta: 0.48
# Episode 82, Total Reward: 22.0, Epsilon: 0.84, Beta: 0.48
# Episode 83, Total Reward: 47.0, Epsilon: 0.83, Beta: 0.48
# Episode 84, Total Reward: 37.0, Epsilon: 0.83, Beta: 0.49
# Episode 85, Total Reward: 43.0, Epsilon: 0.83, Beta: 0.49
# Episode 86, Total Reward: 25.0, Epsilon: 0.83, Beta: 0.49
# Episode 87, Total Reward: 11.0, Epsilon: 0.83, Beta: 0.49
# Episode 88, Total Reward: 16.0, Epsilon: 0.82, Beta: 0.49
# Episode 89, Total Reward: 38.0, Epsilon: 0.82, Beta: 0.49
# Episode 90, Total Reward: 34.0, Epsilon: 0.82, Beta: 0.49
# Episode 91, Total Reward: 26.0, Epsilon: 0.82, Beta: 0.49
# Episode 92, Total Reward: 28.0, Epsilon: 0.82, Beta: 0.49
# Episode 93, Total Reward: 24.0, Epsilon: 0.81, Beta: 0.49
# Episode 94, Total Reward: 16.0, Epsilon: 0.81, Beta: 0.50
# Episode 95, Total Reward: 14.0, Epsilon: 0.81, Beta: 0.50
# Episode 96, Total Reward: 19.0, Epsilon: 0.81, Beta: 0.50
# Episode 97, Total Reward: 30.0, Epsilon: 0.81, Beta: 0.50
# Episode 98, Total Reward: 24.0, Epsilon: 0.80, Beta: 0.50
# Episode 99, Total Reward: 95.0, Epsilon: 0.80, Beta: 0.50
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 100, Total Reward: 50.0, Epsilon: 0.80, Beta: 0.50
# Episode 101, Total Reward: 18.0, Epsilon: 0.80, Beta: 0.50
# Episode 102, Total Reward: 33.0, Epsilon: 0.80, Beta: 0.50
# Episode 103, Total Reward: 18.0, Epsilon: 0.79, Beta: 0.50
# Episode 104, Total Reward: 13.0, Epsilon: 0.79, Beta: 0.51
# Episode 105, Total Reward: 19.0, Epsilon: 0.79, Beta: 0.51
# Episode 106, Total Reward: 19.0, Epsilon: 0.79, Beta: 0.51
# Episode 107, Total Reward: 62.0, Epsilon: 0.79, Beta: 0.51
# Episode 108, Total Reward: 50.0, Epsilon: 0.78, Beta: 0.51
# Episode 109, Total Reward: 21.0, Epsilon: 0.78, Beta: 0.51
# Episode 110, Total Reward: 32.0, Epsilon: 0.78, Beta: 0.51
# Episode 111, Total Reward: 16.0, Epsilon: 0.78, Beta: 0.51
# Episode 112, Total Reward: 10.0, Epsilon: 0.78, Beta: 0.51
# Episode 113, Total Reward: 11.0, Epsilon: 0.77, Beta: 0.51
# Episode 114, Total Reward: 51.0, Epsilon: 0.77, Beta: 0.52
# Episode 115, Total Reward: 93.0, Epsilon: 0.77, Beta: 0.52
# Episode 116, Total Reward: 28.0, Epsilon: 0.77, Beta: 0.52
# Episode 117, Total Reward: 77.0, Epsilon: 0.77, Beta: 0.52
# Episode 118, Total Reward: 21.0, Epsilon: 0.76, Beta: 0.52
# Episode 119, Total Reward: 24.0, Epsilon: 0.76, Beta: 0.52
# Episode 120, Total Reward: 22.0, Epsilon: 0.76, Beta: 0.52
# Episode 121, Total Reward: 27.0, Epsilon: 0.76, Beta: 0.52
# Episode 122, Total Reward: 35.0, Epsilon: 0.76, Beta: 0.52
# Episode 123, Total Reward: 67.0, Epsilon: 0.75, Beta: 0.52
# Episode 124, Total Reward: 55.0, Epsilon: 0.75, Beta: 0.53
# Episode 125, Total Reward: 12.0, Epsilon: 0.75, Beta: 0.53
# Episode 126, Total Reward: 24.0, Epsilon: 0.75, Beta: 0.53
# Episode 127, Total Reward: 16.0, Epsilon: 0.75, Beta: 0.53
# Episode 128, Total Reward: 12.0, Epsilon: 0.74, Beta: 0.53
# Episode 129, Total Reward: 20.0, Epsilon: 0.74, Beta: 0.53
# Episode 130, Total Reward: 25.0, Epsilon: 0.74, Beta: 0.53
# Episode 131, Total Reward: 40.0, Epsilon: 0.74, Beta: 0.53
# Episode 132, Total Reward: 25.0, Epsilon: 0.74, Beta: 0.53
# Episode 133, Total Reward: 26.0, Epsilon: 0.73, Beta: 0.53
# Episode 134, Total Reward: 23.0, Epsilon: 0.73, Beta: 0.54
# Episode 135, Total Reward: 54.0, Epsilon: 0.73, Beta: 0.54
# Episode 136, Total Reward: 18.0, Epsilon: 0.73, Beta: 0.54
# Episode 137, Total Reward: 36.0, Epsilon: 0.73, Beta: 0.54
# Episode 138, Total Reward: 36.0, Epsilon: 0.72, Beta: 0.54
# Episode 139, Total Reward: 108.0, Epsilon: 0.72, Beta: 0.54
# Episode 140, Total Reward: 34.0, Epsilon: 0.72, Beta: 0.54
# Episode 141, Total Reward: 53.0, Epsilon: 0.72, Beta: 0.54
# Episode 142, Total Reward: 38.0, Epsilon: 0.72, Beta: 0.54
# Episode 143, Total Reward: 27.0, Epsilon: 0.71, Beta: 0.54
# Episode 144, Total Reward: 25.0, Epsilon: 0.71, Beta: 0.55
# Episode 145, Total Reward: 27.0, Epsilon: 0.71, Beta: 0.55
# Episode 146, Total Reward: 43.0, Epsilon: 0.71, Beta: 0.55
# Episode 147, Total Reward: 76.0, Epsilon: 0.71, Beta: 0.55
# Episode 148, Total Reward: 36.0, Epsilon: 0.70, Beta: 0.55
# Episode 149, Total Reward: 14.0, Epsilon: 0.70, Beta: 0.55
# Episode 150, Total Reward: 40.0, Epsilon: 0.70, Beta: 0.55
# Episode 151, Total Reward: 83.0, Epsilon: 0.70, Beta: 0.55
# Episode 152, Total Reward: 61.0, Epsilon: 0.70, Beta: 0.55
# Episode 153, Total Reward: 49.0, Epsilon: 0.69, Beta: 0.55
# Episode 154, Total Reward: 32.0, Epsilon: 0.69, Beta: 0.56
# Episode 155, Total Reward: 13.0, Epsilon: 0.69, Beta: 0.56
# Episode 156, Total Reward: 14.0, Epsilon: 0.69, Beta: 0.56
# Episode 157, Total Reward: 18.0, Epsilon: 0.69, Beta: 0.56
# Episode 158, Total Reward: 23.0, Epsilon: 0.68, Beta: 0.56
# Episode 159, Total Reward: 66.0, Epsilon: 0.68, Beta: 0.56
# Episode 160, Total Reward: 31.0, Epsilon: 0.68, Beta: 0.56
# Episode 161, Total Reward: 40.0, Epsilon: 0.68, Beta: 0.56
# Episode 162, Total Reward: 61.0, Epsilon: 0.68, Beta: 0.56
# Episode 163, Total Reward: 21.0, Epsilon: 0.67, Beta: 0.56
# Episode 164, Total Reward: 24.0, Epsilon: 0.67, Beta: 0.57
# Episode 165, Total Reward: 39.0, Epsilon: 0.67, Beta: 0.57
# Episode 166, Total Reward: 28.0, Epsilon: 0.67, Beta: 0.57
# Episode 167, Total Reward: 22.0, Epsilon: 0.67, Beta: 0.57
# Episode 168, Total Reward: 81.0, Epsilon: 0.66, Beta: 0.57
# Episode 169, Total Reward: 54.0, Epsilon: 0.66, Beta: 0.57
# Episode 170, Total Reward: 25.0, Epsilon: 0.66, Beta: 0.57
# Episode 171, Total Reward: 68.0, Epsilon: 0.66, Beta: 0.57
# Episode 172, Total Reward: 116.0, Epsilon: 0.66, Beta: 0.57
# Episode 173, Total Reward: 11.0, Epsilon: 0.65, Beta: 0.57
# Episode 174, Total Reward: 76.0, Epsilon: 0.65, Beta: 0.58
# Episode 175, Total Reward: 43.0, Epsilon: 0.65, Beta: 0.58
# Episode 176, Total Reward: 15.0, Epsilon: 0.65, Beta: 0.58
# Episode 177, Total Reward: 87.0, Epsilon: 0.65, Beta: 0.58
# Episode 178, Total Reward: 21.0, Epsilon: 0.64, Beta: 0.58
# Episode 179, Total Reward: 97.0, Epsilon: 0.64, Beta: 0.58
# Episode 180, Total Reward: 20.0, Epsilon: 0.64, Beta: 0.58
# Episode 181, Total Reward: 26.0, Epsilon: 0.64, Beta: 0.58
# Episode 182, Total Reward: 16.0, Epsilon: 0.64, Beta: 0.58
# Episode 183, Total Reward: 40.0, Epsilon: 0.63, Beta: 0.58
# Episode 184, Total Reward: 172.0, Epsilon: 0.63, Beta: 0.59
# Episode 185, Total Reward: 22.0, Epsilon: 0.63, Beta: 0.59
# Episode 186, Total Reward: 15.0, Epsilon: 0.63, Beta: 0.59
# Episode 187, Total Reward: 84.0, Epsilon: 0.63, Beta: 0.59
# Episode 188, Total Reward: 17.0, Epsilon: 0.62, Beta: 0.59
# Episode 189, Total Reward: 62.0, Epsilon: 0.62, Beta: 0.59
# Episode 190, Total Reward: 29.0, Epsilon: 0.62, Beta: 0.59
# Episode 191, Total Reward: 66.0, Epsilon: 0.62, Beta: 0.59
# Episode 192, Total Reward: 21.0, Epsilon: 0.62, Beta: 0.59
# Episode 193, Total Reward: 78.0, Epsilon: 0.61, Beta: 0.59
# Episode 194, Total Reward: 56.0, Epsilon: 0.61, Beta: 0.60
# Episode 195, Total Reward: 86.0, Epsilon: 0.61, Beta: 0.60
# Episode 196, Total Reward: 17.0, Epsilon: 0.61, Beta: 0.60
# Episode 197, Total Reward: 55.0, Epsilon: 0.61, Beta: 0.60
# Episode 198, Total Reward: 10.0, Epsilon: 0.60, Beta: 0.60
# Episode 199, Total Reward: 24.0, Epsilon: 0.60, Beta: 0.60
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 200, Total Reward: 61.0, Epsilon: 0.60, Beta: 0.60
# Episode 201, Total Reward: 13.0, Epsilon: 0.60, Beta: 0.60
# Episode 202, Total Reward: 58.0, Epsilon: 0.60, Beta: 0.60
# Episode 203, Total Reward: 173.0, Epsilon: 0.59, Beta: 0.60
# Episode 204, Total Reward: 47.0, Epsilon: 0.59, Beta: 0.61
# Episode 205, Total Reward: 56.0, Epsilon: 0.59, Beta: 0.61
# Episode 206, Total Reward: 46.0, Epsilon: 0.59, Beta: 0.61
# Episode 207, Total Reward: 18.0, Epsilon: 0.59, Beta: 0.61
# Episode 208, Total Reward: 76.0, Epsilon: 0.58, Beta: 0.61
# Episode 209, Total Reward: 23.0, Epsilon: 0.58, Beta: 0.61
# Episode 210, Total Reward: 50.0, Epsilon: 0.58, Beta: 0.61
# Episode 211, Total Reward: 35.0, Epsilon: 0.58, Beta: 0.61
# Episode 212, Total Reward: 66.0, Epsilon: 0.58, Beta: 0.61
# Episode 213, Total Reward: 16.0, Epsilon: 0.57, Beta: 0.61
# Episode 214, Total Reward: 25.0, Epsilon: 0.57, Beta: 0.62
# Episode 215, Total Reward: 208.0, Epsilon: 0.57, Beta: 0.62
# Episode 216, Total Reward: 32.0, Epsilon: 0.57, Beta: 0.62
# Episode 217, Total Reward: 33.0, Epsilon: 0.57, Beta: 0.62
# Episode 218, Total Reward: 17.0, Epsilon: 0.56, Beta: 0.62
# Episode 219, Total Reward: 50.0, Epsilon: 0.56, Beta: 0.62
# Episode 220, Total Reward: 127.0, Epsilon: 0.56, Beta: 0.62
# Episode 221, Total Reward: 117.0, Epsilon: 0.56, Beta: 0.62
# Episode 222, Total Reward: 14.0, Epsilon: 0.56, Beta: 0.62
# Episode 223, Total Reward: 13.0, Epsilon: 0.55, Beta: 0.62
# Episode 224, Total Reward: 22.0, Epsilon: 0.55, Beta: 0.63
# Episode 225, Total Reward: 12.0, Epsilon: 0.55, Beta: 0.63
# Episode 226, Total Reward: 52.0, Epsilon: 0.55, Beta: 0.63
# Episode 227, Total Reward: 63.0, Epsilon: 0.55, Beta: 0.63
# Episode 228, Total Reward: 25.0, Epsilon: 0.54, Beta: 0.63
# Episode 229, Total Reward: 59.0, Epsilon: 0.54, Beta: 0.63
# Episode 230, Total Reward: 12.0, Epsilon: 0.54, Beta: 0.63
# Episode 231, Total Reward: 59.0, Epsilon: 0.54, Beta: 0.63
# Episode 232, Total Reward: 39.0, Epsilon: 0.54, Beta: 0.63
# Episode 233, Total Reward: 41.0, Epsilon: 0.53, Beta: 0.63
# Episode 234, Total Reward: 15.0, Epsilon: 0.53, Beta: 0.64
# Episode 235, Total Reward: 57.0, Epsilon: 0.53, Beta: 0.64
# Episode 236, Total Reward: 59.0, Epsilon: 0.53, Beta: 0.64
# Episode 237, Total Reward: 59.0, Epsilon: 0.53, Beta: 0.64
# Episode 238, Total Reward: 24.0, Epsilon: 0.52, Beta: 0.64
# Episode 239, Total Reward: 71.0, Epsilon: 0.52, Beta: 0.64
# Episode 240, Total Reward: 63.0, Epsilon: 0.52, Beta: 0.64
# Episode 241, Total Reward: 12.0, Epsilon: 0.52, Beta: 0.64
# Episode 242, Total Reward: 56.0, Epsilon: 0.52, Beta: 0.64
# Episode 243, Total Reward: 61.0, Epsilon: 0.51, Beta: 0.64
# Episode 244, Total Reward: 20.0, Epsilon: 0.51, Beta: 0.65
# Episode 245, Total Reward: 26.0, Epsilon: 0.51, Beta: 0.65
# Episode 246, Total Reward: 17.0, Epsilon: 0.51, Beta: 0.65
# Episode 247, Total Reward: 15.0, Epsilon: 0.51, Beta: 0.65
# Episode 248, Total Reward: 23.0, Epsilon: 0.50, Beta: 0.65
# Episode 249, Total Reward: 32.0, Epsilon: 0.50, Beta: 0.65
# Episode 250, Total Reward: 47.0, Epsilon: 0.50, Beta: 0.65
# Episode 251, Total Reward: 44.0, Epsilon: 0.50, Beta: 0.65
# Episode 252, Total Reward: 53.0, Epsilon: 0.50, Beta: 0.65
# Episode 253, Total Reward: 13.0, Epsilon: 0.49, Beta: 0.65
# Episode 254, Total Reward: 13.0, Epsilon: 0.49, Beta: 0.66
# Episode 255, Total Reward: 60.0, Epsilon: 0.49, Beta: 0.66
# Episode 256, Total Reward: 12.0, Epsilon: 0.49, Beta: 0.66
# Episode 257, Total Reward: 20.0, Epsilon: 0.49, Beta: 0.66
# Episode 258, Total Reward: 19.0, Epsilon: 0.48, Beta: 0.66
# Episode 259, Total Reward: 44.0, Epsilon: 0.48, Beta: 0.66
# Episode 260, Total Reward: 82.0, Epsilon: 0.48, Beta: 0.66
# Episode 261, Total Reward: 17.0, Epsilon: 0.48, Beta: 0.66
# Episode 262, Total Reward: 172.0, Epsilon: 0.48, Beta: 0.66
# Episode 263, Total Reward: 52.0, Epsilon: 0.47, Beta: 0.66
# Episode 264, Total Reward: 21.0, Epsilon: 0.47, Beta: 0.67
# Episode 265, Total Reward: 19.0, Epsilon: 0.47, Beta: 0.67
# Episode 266, Total Reward: 22.0, Epsilon: 0.47, Beta: 0.67
# Episode 267, Total Reward: 67.0, Epsilon: 0.47, Beta: 0.67
# Episode 268, Total Reward: 19.0, Epsilon: 0.46, Beta: 0.67
# Episode 269, Total Reward: 35.0, Epsilon: 0.46, Beta: 0.67
# Episode 270, Total Reward: 21.0, Epsilon: 0.46, Beta: 0.67
# Episode 271, Total Reward: 16.0, Epsilon: 0.46, Beta: 0.67
# Episode 272, Total Reward: 97.0, Epsilon: 0.46, Beta: 0.67
# Episode 273, Total Reward: 37.0, Epsilon: 0.45, Beta: 0.67
# Episode 274, Total Reward: 73.0, Epsilon: 0.45, Beta: 0.68
# Episode 275, Total Reward: 42.0, Epsilon: 0.45, Beta: 0.68
# Episode 276, Total Reward: 29.0, Epsilon: 0.45, Beta: 0.68
# Episode 277, Total Reward: 129.0, Epsilon: 0.45, Beta: 0.68
# Episode 278, Total Reward: 11.0, Epsilon: 0.44, Beta: 0.68
# Episode 279, Total Reward: 57.0, Epsilon: 0.44, Beta: 0.68
# Episode 280, Total Reward: 12.0, Epsilon: 0.44, Beta: 0.68
# Episode 281, Total Reward: 12.0, Epsilon: 0.44, Beta: 0.68
# Episode 282, Total Reward: 188.0, Epsilon: 0.44, Beta: 0.68
# Episode 283, Total Reward: 107.0, Epsilon: 0.43, Beta: 0.68
# Episode 284, Total Reward: 15.0, Epsilon: 0.43, Beta: 0.69
# Episode 285, Total Reward: 10.0, Epsilon: 0.43, Beta: 0.69
# Episode 286, Total Reward: 13.0, Epsilon: 0.43, Beta: 0.69
# Episode 287, Total Reward: 65.0, Epsilon: 0.43, Beta: 0.69
# Episode 288, Total Reward: 59.0, Epsilon: 0.42, Beta: 0.69
# Episode 289, Total Reward: 128.0, Epsilon: 0.42, Beta: 0.69
# Episode 290, Total Reward: 58.0, Epsilon: 0.42, Beta: 0.69
# Episode 291, Total Reward: 23.0, Epsilon: 0.42, Beta: 0.69
# Episode 292, Total Reward: 141.0, Epsilon: 0.42, Beta: 0.69
# Episode 293, Total Reward: 71.0, Epsilon: 0.41, Beta: 0.69
# Episode 294, Total Reward: 18.0, Epsilon: 0.41, Beta: 0.70
# Episode 295, Total Reward: 78.0, Epsilon: 0.41, Beta: 0.70
# Episode 296, Total Reward: 42.0, Epsilon: 0.41, Beta: 0.70
# Episode 297, Total Reward: 16.0, Epsilon: 0.41, Beta: 0.70
# Episode 298, Total Reward: 31.0, Epsilon: 0.40, Beta: 0.70
# Episode 299, Total Reward: 19.0, Epsilon: 0.40, Beta: 0.70
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 300, Total Reward: 89.0, Epsilon: 0.40, Beta: 0.70
# Episode 301, Total Reward: 12.0, Epsilon: 0.40, Beta: 0.70
# Episode 302, Total Reward: 54.0, Epsilon: 0.40, Beta: 0.70
# Episode 303, Total Reward: 47.0, Epsilon: 0.39, Beta: 0.70
# Episode 304, Total Reward: 98.0, Epsilon: 0.39, Beta: 0.71
# Episode 305, Total Reward: 69.0, Epsilon: 0.39, Beta: 0.71
# Episode 306, Total Reward: 132.0, Epsilon: 0.39, Beta: 0.71
# Episode 307, Total Reward: 117.0, Epsilon: 0.39, Beta: 0.71
# Episode 308, Total Reward: 102.0, Epsilon: 0.38, Beta: 0.71
# Episode 309, Total Reward: 43.0, Epsilon: 0.38, Beta: 0.71
# Episode 310, Total Reward: 23.0, Epsilon: 0.38, Beta: 0.71
# Episode 311, Total Reward: 14.0, Epsilon: 0.38, Beta: 0.71
# Episode 312, Total Reward: 13.0, Epsilon: 0.38, Beta: 0.71
# Episode 313, Total Reward: 176.0, Epsilon: 0.37, Beta: 0.71
# Episode 314, Total Reward: 13.0, Epsilon: 0.37, Beta: 0.72
# Episode 315, Total Reward: 169.0, Epsilon: 0.37, Beta: 0.72
# Episode 316, Total Reward: 141.0, Epsilon: 0.37, Beta: 0.72
# Episode 317, Total Reward: 35.0, Epsilon: 0.37, Beta: 0.72
# Episode 318, Total Reward: 11.0, Epsilon: 0.36, Beta: 0.72
# Episode 319, Total Reward: 337.0, Epsilon: 0.36, Beta: 0.72
# Episode 320, Total Reward: 36.0, Epsilon: 0.36, Beta: 0.72
# Episode 321, Total Reward: 143.0, Epsilon: 0.36, Beta: 0.72
# Episode 322, Total Reward: 44.0, Epsilon: 0.36, Beta: 0.72
# Episode 323, Total Reward: 226.0, Epsilon: 0.35, Beta: 0.72
# Episode 324, Total Reward: 213.0, Epsilon: 0.35, Beta: 0.73
# Episode 325, Total Reward: 139.0, Epsilon: 0.35, Beta: 0.73
# Episode 326, Total Reward: 411.0, Epsilon: 0.35, Beta: 0.73
# Episode 327, Total Reward: 188.0, Epsilon: 0.35, Beta: 0.73
# Episode 328, Total Reward: 37.0, Epsilon: 0.34, Beta: 0.73
# Episode 329, Total Reward: 16.0, Epsilon: 0.34, Beta: 0.73
# Episode 330, Total Reward: 119.0, Epsilon: 0.34, Beta: 0.73
# Episode 331, Total Reward: 14.0, Epsilon: 0.34, Beta: 0.73
# Episode 332, Total Reward: 254.0, Epsilon: 0.34, Beta: 0.73
# Episode 333, Total Reward: 16.0, Epsilon: 0.33, Beta: 0.73
# Episode 334, Total Reward: 185.0, Epsilon: 0.33, Beta: 0.74
# Episode 335, Total Reward: 336.0, Epsilon: 0.33, Beta: 0.74
# Episode 336, Total Reward: 11.0, Epsilon: 0.33, Beta: 0.74
# Episode 337, Total Reward: 134.0, Epsilon: 0.33, Beta: 0.74
# Episode 338, Total Reward: 82.0, Epsilon: 0.32, Beta: 0.74
# Episode 339, Total Reward: 196.0, Epsilon: 0.32, Beta: 0.74
# Episode 340, Total Reward: 16.0, Epsilon: 0.32, Beta: 0.74
# Episode 341, Total Reward: 20.0, Epsilon: 0.32, Beta: 0.74
# Episode 342, Total Reward: 163.0, Epsilon: 0.32, Beta: 0.74
# Episode 343, Total Reward: 17.0, Epsilon: 0.31, Beta: 0.74
# Episode 344, Total Reward: 214.0, Epsilon: 0.31, Beta: 0.75
# Episode 345, Total Reward: 268.0, Epsilon: 0.31, Beta: 0.75
# Episode 346, Total Reward: 180.0, Epsilon: 0.31, Beta: 0.75
# Episode 347, Total Reward: 15.0, Epsilon: 0.31, Beta: 0.75
# Episode 348, Total Reward: 13.0, Epsilon: 0.30, Beta: 0.75
# Episode 349, Total Reward: 114.0, Epsilon: 0.30, Beta: 0.75
# Episode 350, Total Reward: 184.0, Epsilon: 0.30, Beta: 0.75
# Episode 351, Total Reward: 133.0, Epsilon: 0.30, Beta: 0.75
# Episode 352, Total Reward: 155.0, Epsilon: 0.30, Beta: 0.75
# Episode 353, Total Reward: 69.0, Epsilon: 0.29, Beta: 0.75
# Episode 354, Total Reward: 10.0, Epsilon: 0.29, Beta: 0.76
# Episode 355, Total Reward: 15.0, Epsilon: 0.29, Beta: 0.76
# Episode 356, Total Reward: 13.0, Epsilon: 0.29, Beta: 0.76
# Episode 357, Total Reward: 11.0, Epsilon: 0.29, Beta: 0.76
# Episode 358, Total Reward: 15.0, Epsilon: 0.28, Beta: 0.76
# Episode 359, Total Reward: 200.0, Epsilon: 0.28, Beta: 0.76
# Episode 360, Total Reward: 72.0, Epsilon: 0.28, Beta: 0.76
# Episode 361, Total Reward: 224.0, Epsilon: 0.28, Beta: 0.76
# Episode 362, Total Reward: 55.0, Epsilon: 0.28, Beta: 0.76
# Episode 363, Total Reward: 15.0, Epsilon: 0.27, Beta: 0.76
# Episode 364, Total Reward: 20.0, Epsilon: 0.27, Beta: 0.77
# Episode 365, Total Reward: 156.0, Epsilon: 0.27, Beta: 0.77
# Episode 366, Total Reward: 214.0, Epsilon: 0.27, Beta: 0.77
# Episode 367, Total Reward: 21.0, Epsilon: 0.27, Beta: 0.77
# Episode 368, Total Reward: 15.0, Epsilon: 0.26, Beta: 0.77
# Episode 369, Total Reward: 15.0, Epsilon: 0.26, Beta: 0.77
# Episode 370, Total Reward: 10.0, Epsilon: 0.26, Beta: 0.77
# Episode 371, Total Reward: 30.0, Epsilon: 0.26, Beta: 0.77
# Episode 372, Total Reward: 302.0, Epsilon: 0.26, Beta: 0.77
# Episode 373, Total Reward: 12.0, Epsilon: 0.25, Beta: 0.77
# Episode 374, Total Reward: 13.0, Epsilon: 0.25, Beta: 0.78
# Episode 375, Total Reward: 135.0, Epsilon: 0.25, Beta: 0.78
# Episode 376, Total Reward: 119.0, Epsilon: 0.25, Beta: 0.78
# Episode 377, Total Reward: 140.0, Epsilon: 0.25, Beta: 0.78
# Episode 378, Total Reward: 329.0, Epsilon: 0.24, Beta: 0.78
# Episode 379, Total Reward: 139.0, Epsilon: 0.24, Beta: 0.78
# Episode 380, Total Reward: 263.0, Epsilon: 0.24, Beta: 0.78
# Episode 381, Total Reward: 95.0, Epsilon: 0.24, Beta: 0.78
# Episode 382, Total Reward: 113.0, Epsilon: 0.24, Beta: 0.78
# Episode 383, Total Reward: 297.0, Epsilon: 0.23, Beta: 0.78
# Episode 384, Total Reward: 14.0, Epsilon: 0.23, Beta: 0.79
# Episode 385, Total Reward: 214.0, Epsilon: 0.23, Beta: 0.79
# Episode 386, Total Reward: 195.0, Epsilon: 0.23, Beta: 0.79
# Episode 387, Total Reward: 80.0, Epsilon: 0.23, Beta: 0.79
# Episode 388, Total Reward: 149.0, Epsilon: 0.22, Beta: 0.79
# Episode 389, Total Reward: 19.0, Epsilon: 0.22, Beta: 0.79
# Episode 390, Total Reward: 176.0, Epsilon: 0.22, Beta: 0.79
# Episode 391, Total Reward: 233.0, Epsilon: 0.22, Beta: 0.79
# Episode 392, Total Reward: 151.0, Epsilon: 0.22, Beta: 0.79
# Episode 393, Total Reward: 325.0, Epsilon: 0.21, Beta: 0.79
# Episode 394, Total Reward: 19.0, Epsilon: 0.21, Beta: 0.80
# Episode 395, Total Reward: 181.0, Epsilon: 0.21, Beta: 0.80
# Episode 396, Total Reward: 58.0, Epsilon: 0.21, Beta: 0.80
# Episode 397, Total Reward: 326.0, Epsilon: 0.21, Beta: 0.80
# Episode 398, Total Reward: 147.0, Epsilon: 0.20, Beta: 0.80
# Episode 399, Total Reward: 17.0, Epsilon: 0.20, Beta: 0.80
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Episode 400, Total Reward: 366.0, Epsilon: 0.20, Beta: 0.80
# Episode 401, Total Reward: 302.0, Epsilon: 0.20, Beta: 0.80
# Episode 402, Total Reward: 378.0, Epsilon: 0.20, Beta: 0.80
# Episode 403, Total Reward: 324.0, Epsilon: 0.19, Beta: 0.80
# Episode 404, Total Reward: 230.0, Epsilon: 0.19, Beta: 0.81
# Episode 405, Total Reward: 295.0, Epsilon: 0.19, Beta: 0.81
# Episode 406, Total Reward: 427.0, Epsilon: 0.19, Beta: 0.81
# Episode 407, Total Reward: 346.0, Epsilon: 0.19, Beta: 0.81
# Episode 408, Total Reward: 180.0, Epsilon: 0.18, Beta: 0.81
# Episode 409, Total Reward: 204.0, Epsilon: 0.18, Beta: 0.81
# Episode 410, Total Reward: 17.0, Epsilon: 0.18, Beta: 0.81
# Episode 411, Total Reward: 181.0, Epsilon: 0.18, Beta: 0.81
# Episode 412, Total Reward: 274.0, Epsilon: 0.18, Beta: 0.81
# Episode 413, Total Reward: 38.0, Epsilon: 0.17, Beta: 0.81
# Episode 414, Total Reward: 341.0, Epsilon: 0.17, Beta: 0.82
# Episode 415, Total Reward: 312.0, Epsilon: 0.17, Beta: 0.82
# Episode 416, Total Reward: 192.0, Epsilon: 0.17, Beta: 0.82
# Episode 417, Total Reward: 295.0, Epsilon: 0.17, Beta: 0.82
# Episode 418, Total Reward: 20.0, Epsilon: 0.16, Beta: 0.82
# Episode 419, Total Reward: 30.0, Epsilon: 0.16, Beta: 0.82
# Episode 420, Total Reward: 159.0, Epsilon: 0.16, Beta: 0.82
# Episode 421, Total Reward: 311.0, Epsilon: 0.16, Beta: 0.82
# Episode 422, Total Reward: 260.0, Epsilon: 0.16, Beta: 0.82
# Episode 423, Total Reward: 325.0, Epsilon: 0.15, Beta: 0.82
# Episode 424, Total Reward: 31.0, Epsilon: 0.15, Beta: 0.83
# Episode 425, Total Reward: 304.0, Epsilon: 0.15, Beta: 0.83
# Episode 426, Total Reward: 325.0, Epsilon: 0.15, Beta: 0.83
# Episode 427, Total Reward: 23.0, Epsilon: 0.15, Beta: 0.83
# Episode 428, Total Reward: 298.0, Epsilon: 0.14, Beta: 0.83
# Episode 429, Total Reward: 290.0, Epsilon: 0.14, Beta: 0.83
# Episode 430, Total Reward: 237.0, Epsilon: 0.14, Beta: 0.83
# Episode 431, Total Reward: 16.0, Epsilon: 0.14, Beta: 0.83
# Episode 432, Total Reward: 53.0, Epsilon: 0.14, Beta: 0.83
# Episode 433, Total Reward: 24.0, Epsilon: 0.13, Beta: 0.83
# Episode 434, Total Reward: 351.0, Epsilon: 0.13, Beta: 0.84
# Episode 435, Total Reward: 290.0, Epsilon: 0.13, Beta: 0.84
# Episode 436, Total Reward: 14.0, Epsilon: 0.13, Beta: 0.84
# Episode 437, Total Reward: 291.0, Epsilon: 0.13, Beta: 0.84
# Episode 438, Total Reward: 418.0, Epsilon: 0.12, Beta: 0.84
# Episode 439, Total Reward: 27.0, Epsilon: 0.12, Beta: 0.84
# Episode 440, Total Reward: 311.0, Epsilon: 0.12, Beta: 0.84
# Episode 441, Total Reward: 47.0, Epsilon: 0.12, Beta: 0.84
# Episode 442, Total Reward: 175.0, Epsilon: 0.12, Beta: 0.84
# Episode 443, Total Reward: 311.0, Epsilon: 0.11, Beta: 0.84
# Episode 444, Total Reward: 500.0, Epsilon: 0.11, Beta: 0.85
# Episode 445, Total Reward: 24.0, Epsilon: 0.11, Beta: 0.85
# Episode 446, Total Reward: 117.0, Epsilon: 0.11, Beta: 0.85
# Episode 447, Total Reward: 19.0, Epsilon: 0.11, Beta: 0.85
# Episode 448, Total Reward: 75.0, Epsilon: 0.10, Beta: 0.85
# Episode 449, Total Reward: 278.0, Epsilon: 0.10, Beta: 0.85
# Episode 450, Total Reward: 227.0, Epsilon: 0.10, Beta: 0.85
# Episode 451, Total Reward: 297.0, Epsilon: 0.10, Beta: 0.85
# Episode 452, Total Reward: 24.0, Epsilon: 0.10, Beta: 0.85
# Episode 453, Total Reward: 325.0, Epsilon: 0.09, Beta: 0.85
# Episode 454, Total Reward: 500.0, Epsilon: 0.09, Beta: 0.86
# Episode 455, Total Reward: 318.0, Epsilon: 0.09, Beta: 0.86
# Episode 456, Total Reward: 63.0, Epsilon: 0.09, Beta: 0.86
# Episode 457, Total Reward: 497.0, Epsilon: 0.09, Beta: 0.86
# Episode 458, Total Reward: 500.0, Epsilon: 0.08, Beta: 0.86
# Episode 459, Total Reward: 160.0, Epsilon: 0.08, Beta: 0.86
# Episode 460, Total Reward: 500.0, Epsilon: 0.08, Beta: 0.86
# Episode 461, Total Reward: 268.0, Epsilon: 0.08, Beta: 0.86
# Episode 462, Total Reward: 500.0, Epsilon: 0.08, Beta: 0.86
# Episode 463, Total Reward: 119.0, Epsilon: 0.07, Beta: 0.86
# Episode 464, Total Reward: 53.0, Epsilon: 0.07, Beta: 0.87
# Episode 465, Total Reward: 18.0, Epsilon: 0.07, Beta: 0.87
# Episode 466, Total Reward: 124.0, Epsilon: 0.07, Beta: 0.87
# Episode 467, Total Reward: 266.0, Epsilon: 0.07, Beta: 0.87
# Episode 468, Total Reward: 242.0, Epsilon: 0.06, Beta: 0.87
# Episode 469, Total Reward: 500.0, Epsilon: 0.06, Beta: 0.87
# Episode 470, Total Reward: 500.0, Epsilon: 0.06, Beta: 0.87
# Episode 471, Total Reward: 500.0, Epsilon: 0.06, Beta: 0.87
# Episode 472, Total Reward: 318.0, Epsilon: 0.06, Beta: 0.87
# Episode 473, Total Reward: 463.0, Epsilon: 0.05, Beta: 0.87
# Episode 474, Total Reward: 500.0, Epsilon: 0.05, Beta: 0.88
# Episode 475, Total Reward: 500.0, Epsilon: 0.05, Beta: 0.88
# Episode 476, Total Reward: 500.0, Epsilon: 0.05, Beta: 0.88
# Episode 477, Total Reward: 500.0, Epsilon: 0.05, Beta: 0.88
# Episode 478, Total Reward: 500.0, Epsilon: 0.04, Beta: 0.88
# Episode 479, Total Reward: 500.0, Epsilon: 0.04, Beta: 0.88
# Episode 480, Total Reward: 338.0, Epsilon: 0.04, Beta: 0.88
# Episode 481, Total Reward: 500.0, Epsilon: 0.04, Beta: 0.88
# Episode 482, Total Reward: 500.0, Epsilon: 0.04, Beta: 0.88
# Episode 483, Total Reward: 72.0, Epsilon: 0.03, Beta: 0.88
# Episode 484, Total Reward: 500.0, Epsilon: 0.03, Beta: 0.89
# Episode 485, Total Reward: 477.0, Epsilon: 0.03, Beta: 0.89
# Episode 486, Total Reward: 500.0, Epsilon: 0.03, Beta: 0.89
# Episode 487, Total Reward: 500.0, Epsilon: 0.03, Beta: 0.89
# Episode 488, Total Reward: 500.0, Epsilon: 0.02, Beta: 0.89
# Episode 489, Total Reward: 500.0, Epsilon: 0.02, Beta: 0.89
# Episode 490, Total Reward: 500.0, Epsilon: 0.02, Beta: 0.89
# Episode 491, Total Reward: 500.0, Epsilon: 0.02, Beta: 0.89
# Episode 492, Total Reward: 500.0, Epsilon: 0.02, Beta: 0.89
# Episode 493, Total Reward: 500.0, Epsilon: 0.01, Beta: 0.89
# Episode 494, Total Reward: 500.0, Epsilon: 0.01, Beta: 0.90
# Episode 495, Total Reward: 500.0, Epsilon: 0.01, Beta: 0.90
# Episode 496, Total Reward: 500.0, Epsilon: 0.01, Beta: 0.90
# Episode 497, Total Reward: 500.0, Epsilon: 0.01, Beta: 0.90
# Episode 498, Total Reward: 500.0, Epsilon: 0.01, Beta: 0.90
# Episode 499, Total Reward: 500.0, Epsilon: 0.01, Beta: 0.90

# %%
generate_video(policy_net)
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 5))
X = np.linspace(1, len(rewards_per_episode_1), len(rewards_per_episode_1))
plt.plot(X, rewards_per_episode_1, label="Sans PER", alpha=0.7)
plt.plot(X, rewards_per_episode_2, label="Avec PER", alpha=0.7)
plt.xlabel("Éapisode")
plt.ylabel("Récompense moyenne")
plt.title("Comparaison des performances DDQN avec et sans PER")
plt.legend()
plt.show()

# %%
# !pip install ale-py
# !pip install gym[atari]
# !pip install gym[accept-rom-license]
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.11/dist-packages (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ale-py) (1.26.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from ale-py) (6.5.2)
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.11/dist-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym[atari]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym[atari]) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym[atari]) (0.0.8)
# Requirement already satisfied: ale-py~=0.8.0 in /usr/local/lib/python3.11/dist-packages (from gym[atari]) (0.8.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from ale-py~=0.8.0->gym[atari]) (6.5.2)
# Requirement already satisfied: gym[accept-rom-license] in /usr/local/lib/python3.11/dist-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym[accept-rom-license]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym[accept-rom-license]) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym[accept-rom-license]) (0.0.8)
# Requirement already satisfied: autorom~=0.4.2 in /usr/local/lib/python3.11/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (8.1.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (4.67.1)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.11/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gym[accept-rom-license]) (2025.1.31)

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import cv2

# Set device based on availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the neural network for the Q-learning model
class QNetwork(nn.Module):
    def __init__(self, action_size):
        super(QNetwork, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(7 * 7 * 64, 512)
        self.fc2 = nn.Linear(512, action_size)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.relu(self.conv2(x))
        x = torch.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        return self.fc2(x)

# Preprocess the observation
def preprocess(obs):
    if obs is None or obs.size == 0:
        raise ValueError("Observation is empty or None")

    if len(obs.shape) == 3:
        obs = np.mean(obs, axis=2).astype(np.uint8)

    obs = obs[34:194, :]  # Crop the playing area

    if obs.size == 0:
        raise ValueError("Cropped observation is empty")

    obs = cv2.resize(obs, (84, 84))
    obs = obs / 255.0

    # Supprimer l'ajout du canal supplémentaire
    return obs


# Hyperparameters
BUFFER_SIZE = 100000
BATCH_SIZE = 32
GAMMA = 0.99
LR = 0.0001
EPSILON_START = 1.0
EPSILON_END = 0.1
EPSILON_DECAY = 50000
TARGET_UPDATE = 1000
NUM_EPISODES = 5000

# Setup environment
env = gym.make("ALE/Breakout-v5")
action_size = env.action_space.n

# Create two Q-networks
q_network_1 = QNetwork(action_size).to(device)
q_network_2 = QNetwork(action_size).to(device)
target_network_1 = QNetwork(action_size).to(device)
target_network_2 = QNetwork(action_size).to(device)

# Copy weights to target networks
target_network_1.load_state_dict(q_network_1.state_dict())
target_network_2.load_state_dict(q_network_2.state_dict())

optimizer_1 = optim.Adam(q_network_1.parameters(), lr=LR)
optimizer_2 = optim.Adam(q_network_2.parameters(), lr=LR)

memory = deque(maxlen=BUFFER_SIZE)

# Exploration decay
def get_epsilon(step):
    return EPSILON_END + (EPSILON_START - EPSILON_END) * np.exp(-1.0 * step / EPSILON_DECAY)

# Store experience
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = zip(*batch)
        return (np.array(state), np.array(action), np.array(reward),
                np.array(next_state), np.array(done))

    def __len__(self):
        return len(self.buffer)

replay_buffer = ReplayBuffer(BUFFER_SIZE)

# Train the model
def train():
    if len(replay_buffer) < BATCH_SIZE:
        return

    state, action, reward, next_state, done = replay_buffer.sample(BATCH_SIZE)

    state = torch.tensor(state, dtype=torch.float32).to(device)
    next_state = torch.tensor(next_state, dtype=torch.float32).to(device)
    action = torch.tensor(action, dtype=torch.long).to(device)
    reward = torch.tensor(reward, dtype=torch.float32).to(device)
    done = torch.tensor(done, dtype=torch.float32).to(device)

    # Double Q-Learning update
    with torch.no_grad():
        q1_next = q_network_1(next_state).float()
        q2_next = q_network_2(next_state).float()
        best_actions = torch.argmax(q1_next, dim=1)
        q1_target = target_network_1(next_state)
        q2_target = target_network_2(next_state)
        next_q_values = reward + GAMMA * q2_target.gather(1, best_actions.unsqueeze(1)).squeeze(1) * (1 - done)

    # Q1 update
    q1_values = q_network_1(state).gather(1, action.unsqueeze(1)).squeeze(1)
    loss_1 = nn.MSELoss()(q1_values, next_q_values)
    optimizer_1.zero_grad()
    loss_1.backward()
    optimizer_1.step()

    # Q2 update
    with torch.no_grad():
        best_actions_2 = torch.argmax(q2_next, dim=1)
        next_q_values_2 = reward + GAMMA * q1_target.gather(1, best_actions_2.unsqueeze(1)).squeeze(1) * (1 - done)

    q2_values = q_network_2(state).gather(1, action.unsqueeze(1)).squeeze(1)
    loss_2 = nn.MSELoss()(q2_values, next_q_values_2)
    optimizer_2.zero_grad()
    loss_2.backward()
    optimizer_2.step()

def generate_video(env_name="ALE/Breakout-v5", num_episodes=1, max_steps_per_episode=1000, video_filename='pong_env_video.mp4'):
    frames = []
    env = gym.make(env_name, render_mode="rgb_array")

    for episode in range(num_episodes):
        state, _ = env.reset()
        state = preprocess(state)
        state = np.stack([state] * 4, axis=0)
        terminal = False
        current_step = 0

        while not terminal and current_step < max_steps_per_episode:
            frame = env.render()
            if frame is not None and len(frame.shape) == 3:
                frames.append(frame)

            # Choose action
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            q1_values = q_network_1(state_tensor)
            action = torch.argmax(q1_values).item()

            next_state, reward, terminal, _, _ = env.step(action)
            next_state = preprocess(next_state)
            state = np.append(state[1:], np.expand_dims(next_state, 0), axis=0)

            current_step += 1

    env.close()

    if frames:
        imageio.mimsave(video_filename, frames, fps=30)
        display(Video(video_filename, embed=True))
    else:
        print("No frames captured.")


# Main training loop
for episode in range(NUM_EPISODES):
    print(f'episode: {episode}')
    state, _ = env.reset()
    state = preprocess(state)
    state = np.stack([state] * 4, axis=0)

    total_reward = 0
    done = False
    step = 0
    max_steps_per_episode = 500

    while not done and step < max_steps_per_episode:
        epsilon = get_epsilon(step)
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            q1_values = q_network_1(state_tensor)
            action = torch.argmax(q1_values).item()

        next_state, reward, done, _, _ = env.step(action)
        next_state = preprocess(next_state)
        next_state = np.append(state[1:], np.expand_dims(next_state, 0), axis=0)

        replay_buffer.push(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        train()

        if step % TARGET_UPDATE == 0:
            target_network_1.load_state_dict(q_network_1.state_dict())
            target_network_2.load_state_dict(q_network_2.state_dict())

        step += 1

    print(f"Episode {episode+1}: Total Reward: {total_reward}")
    if (episode + 1) % 100 == 0:
        generate_video()

env.close()
# Out:
# episode: 0
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ed807e03c1a1> in <cell line: 0>()
#     207         total_reward += reward
#     208
# --> 209         train()
#     210
#     211         if step % TARGET_UPDATE == 0:
#
# <ipython-input-2-ed807e03c1a1> in train()
#     120         q2_next = q_network_2(next_state).float()
#     121         best_actions = torch.argmax(q1_next, dim=1)
# --> 122         q1_target = target_network_1(next_state)
#     123         q2_target = target_network_2(next_state)
#     124         next_q_values = reward + GAMMA * q2_target.gather(1, best_actions.unsqueeze(1)).squeeze(1) * (1 - done)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-2-ed807e03c1a1> in forward(self, x)
#      26         x = torch.relu(self.conv3(x))
#      27         x = x.view(x.size(0), -1)
# ---> 28         x = torch.relu(self.fc1(x))
#      29         return self.fc2(x)
#      30
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
